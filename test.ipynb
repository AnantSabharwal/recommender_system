# %%
import pickle
import requests
import ast
import json
import pandas as pd

# %%
response = requests.get('http://127.0.0.1:8000/movie_based?movie={}'.format('Toy Story (1995)'))
data = ast.literal_eval(response.content.decode('UTF-8'))

# %%
links = pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
data = pd.DataFrame(data,columns=['title'])

# %%
data = pd.merge(data,movies,on='title')
data = pd.merge(data,links,on='movieId')
data
# Out:
#                                                title  movieId  \
# 0                               Bug's Life, A (1998)     2355
# 1                                 Toy Story 2 (1999)     3114
# 2             Wallace & Gromit: A Close Shave (1995)      745
# 3                                       Shrek (2001)     4306
# 4                    Who Framed Roger Rabbit? (1988)     2987
# 5                                   Space Jam (1996)      673
# 6            Sinbad: Legend of the Seven Seas (2003)     6536
# 7         Cat Returns, The (Neko no ongaeshi) (2002)    27731
# 8                                     Jumanji (1995)        2
# 9  Wallace & Gromit in The Curse of the Were-Rabb...    38038
#
#                                               genres  imdbId   tmdbId
# 0                Adventure|Animation|Children|Comedy  120623   9487.0
# 1        Adventure|Animation|Children|Comedy|Fantasy  120363    863.0
# 2                          Animation|Children|Comedy  112691    532.0
# 3  Adventure|Animation|Children|Comedy|Fantasy|Ro...  126029    808.0
# 4  Adventure|Animation|Children|Comedy|Crime|Fant...   96438    856.0
# 5  Adventure|Animation|Children|Comedy|Fantasy|Sc...  117705   2300.0
# 6               Adventure|Animation|Children|Fantasy  165982  14411.0
# 7               Adventure|Animation|Children|Fantasy  347618  15370.0
# 8                         Adventure|Children|Fantasy  113497   8844.0
# 9                Adventure|Animation|Children|Comedy  312004    533.0

# %%
response = requests.get('http://127.0.0.1:8000/movie_user_based?movie={}'.format('toy story'))
data = ast.literal_eval(response.content.decode('UTF-8'))
for i in data:
    print(data[i])
# Out:
# Back to the Future (1985)
# Groundhog Day (1993)
# Mission: Impossible (1996)
# Star Wars: Episode VI - Return of the Jedi (1983)
# Lion King, The (1994)
# Forrest Gump (1994)
# Star Wars: Episode IV - A New Hope (1977)
# Independence Day (a.k.a. ID4) (1996)
# Jurassic Park (1993)
# Toy Story 2 (1999)
